# %%
# coding: utf-8

# %%
user_config = {
    "account": "pengym_111@163.com",
    "password": "hvwoTxJndBEi8B4G",
    "imap_server": "imap.163.com",
    "imap_port": 993,
    "smtp_server": "smtp.163.com",
    "smtp_port": 25
}

# %% [markdown]
# ## 接收邮件

# %%
import imapy

# %% [markdown]
# ### 登录

# %%
mailbox = imapy.connect(
    host = user_config['imap_server'],
    username = user_config['account'],
    password = user_config['password'],
    ssl = True
)

# %% [markdown]
# ### 解析邮件内容

# %%
def show_messages(messages):
    for msg in messages:
        print('-'*100)
        print('Subject: ', msg['subject'])
        print('From: ', msg['from_email'])
        print('To: ', msg['to'])
        print('Date: ', msg['date'])
        print('*'*100)
        print('Content: ')
        content = msg['text'][0]['text']
        print(content)
        print('Attachments: ', msg['attachments'])
        print('*'*100)

# %%
mailbox.folders()
# Out:
# ['INBOX', '草稿箱', '已发送', '已删除', '垃圾邮件', '病毒文件夹', '订阅邮件']

# %%
messages = mailbox.folder('INBOX').emails()

# %%
show_messages(messages)
# Out:
# ----------------------------------------------------------------------------------------------------
# Subject:  网易邮箱提醒：一次被阻止的收信行为
# From:  mail@service.netease.com
# To:  "pengym_111@163.com" <pengym_111@163.com
# Date:  Mon, 11 Dec 2017 23:38:59 +0800 (CST)
# ****************************************************************************************************
# Content:
# <meta charset="UTF-8" />
# <table align="center" style="font-family:Microsoft YaHei,Simsun;width:540px;table-layout:fixed;" bgcolor="#ffffff" cellpadding="0" cellspacing="0">
# <tbody>
#     <tr>
#         <td style="display:none;"></td>
# </tr>
# <tr>
#     <td>
#         <table style="width:540px;" border="0" cellpadding="0" cellspacing="0">
# <tr>
#     <td style="width:540px;height:100px;font-family:Microsoft YaHei,Simsun;background:#ffffff;"><img src="http://mimg.127.net/hxm/dashi/external/notify/14851528754240068.png" style="display:block;border:0;width: 540px;height: 100px;"/></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
#     <td>
#         <table style="width:540px;" border="0" cellpadding="0" cellspacing="0">
# <tr>
#     <td style="width:540px;height:100px;font-family:Microsoft YaHei,Simsun;"><img src="http://mimg.127.net/hxm/dashi/external/notify/14851528754310069.png" style="display:block;border:0;width: 540px;"/></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
#     <td>
#         <table style="width:540px;" border="0" cellpadding="0" cellspacing="0">
# <tr>
#     <td style="width:540px;height:189px;font-family:Microsoft YaHei,Simsun;background:#ececec;"><img src="http://mimg.127.net/hxm/dashi/external/notify/14851528754410070.png" style="display:block;border:0;width: 540px;"/></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
#     <td>
#         <table style="width:540px;" border="0" cellpadding="0" cellspacing="0">
# <tr>
#     <td style="width:42px;height:19px;font-family:Microsoft YaHei,Simsun;background:#ececec;"><img src="http://mimg.127.net/hxm/dashi/external/notify/14851528754490071.png" style="display:block;border:0;height: 19px;"/></td>
# <td style="width:79px;height:19px;font-family:Microsoft YaHei,Simsun;background:#fafafa;"><a style="display: block;" href="https://mail.163.com/dashi" target="_blank"><img src="http://mimg.127.net/hxm/dashi/external/notify/14851528754550072.png"
#     style="display:block;border:0;height: 19px;"/></a>
# </td>
# <td style="width:419px;height:19px;font-family:Microsoft YaHei,Simsun;background:#fafafa;"><img src="http://mimg.127.net/hxm/dashi/external/notify/14851528754620073.png" style="display:block;border:0;height: 19px;"/></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
#     <td>
#         <table style="width:540px;" border="0" cellpadding="0" cellspacing="0">
# <tr>
#     <td style="width:540px;height:45px;font-family:Microsoft YaHei,Simsun;background:#ececec;"><img src="http://mimg.127.net/hxm/dashi/external/notify/14851528754690074.png" style="display:block;border:0;width: 540px;"/></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
#     <td>
#         <table style="width:540px;" border="0" cellpadding="0" cellspacing="0">
# <tr>
#     <td style="width:42px;height:18px;font-family:Microsoft YaHei,Simsun;background:#ececec;"><img src="http://mimg.127.net/hxm/dashi/external/notify/14851528754760075.png" style="display:block;border:0;height: 18px;"/></td>
# <td style="width:53px;height:18px;font-family:Microsoft YaHei,Simsun;background:#fafafa;"><a style="display: block;" href="http://reg.163.com/userLoginInfo.jsp?username" target="_blank"><img src="http://mimg.127.net/hxm/dashi/external/notify/14851528754820076.png"
#     style="display:block;border:0;height: 18px;"/></a>
# </td>
# <td style="width:445px;height:18px;font-family:Microsoft YaHei,Simsun;background:#fafafa;"><img src="http://mimg.127.net/hxm/dashi/external/notify/14851528754900077.png" style="display:block;border:0;height: 18px;"/></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
#     <td>
#         <table style="width:540px;" border="0" cellpadding="0" cellspacing="0">
# <tr>
#     <td style="width:540px;height:123px;font-family:Microsoft YaHei,Simsun;background:#ececec;position: relative;"><p style="position: absolute;color: #919499;font-size: 12px;left: 31px;top:40px;padding: 0;margin: 0;line-height: 14px;">网易邮件中心&nbsp;&nbsp;&nbsp;2017年12月11日</p>
# <img src="http://mimg.127.net/hxm/dashi/external/notify/14851528754970078.png" style="display:block;border:0;width: 540px;"/></td>
# </tr>
# </table>
# </td>
# </tr>
# </tbody>
# </table>
#
# Attachments:  []
# ****************************************************************************************************
# ----------------------------------------------------------------------------------------------------
# Subject:  Test
# From:  11510035@mail.sustc.edu.cn
# To:  pengym_111@163.com
# Date:  Tue, 12 Dec 2017 11:09:30 +0800
# ****************************************************************************************************
# Content:
# Hello world
#
# 树礼书院
# 彭一明
#
# Attachments:  []
# ****************************************************************************************************

# %% [markdown]
# ### 根据给定条件过滤邮件

# %%
# Get emails in Sent folder:
messages = mailbox.folder('已发送').emails()

# %%
show_messages(messages)
# Out:
# ----------------------------------------------------------------------------------------------------
# Subject:  辣鸡，Project 做完了吗?
# From:  pengym_111@163.com
# To:  1048217874@qq.com
# Date:  Tue, 12 Dec 2017 21:00:21 +0800
# ****************************************************************************************************
# Content:
# hhhhh
# Attachments:  [{'filename': 'lenna.jpeg', 'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x13\x13\x12\x15\x13\x13\x13\x15\x16\x15\x17\x18\x18\x17\x17\x17\x18\x18\x17\x17\x17\x17\x17\x18\x18\x18\x18\x17\x15\x18\x17\x18\x1d( \x18\x1a%\x1d\x17\x16!1!%)+...\x17\x1f383-7(-.+\x01\n\n\n\x0e\r\x0e\x1b\x10\x10\x1a-%\x1f%//----------/-------------------------------------\xff\xc0\x00\x11\x08\x00\xe1\x00\xe1\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x02\x03\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x06\x02\x03\x04\x00\x07\x01\x08\xff\xc4\x00C\x10\x00\x01\x03\x01\x05\x05\x04\x06\x08\x04\x07\x00\x03\x01\x00\x00\x01\x00\x02\x11\x03\x04\x05\x12!1\x06AQaq\x13"\x81\x91#2B\xa1\xb1\xc1\x143Rbr\xd1\xe1\xf0\x07\x82\x92\xf1\x15$CSc\xa2\xc24s\xb3\x16\xff\xc4\x00\x1a\x01\x00\x03\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x03\x04\x01\x00\x05\x06\xff\xc4\x00-\x11\x00\x02\x02\x01\x03\x04\x01\x03\x03\x04\x03\x00\x00\x00\x00\x00\x00\x01\x02\x11\x03\x12!1\x04"2AQ3Bq\x13#\x81\x14\xa1\xb1\xe1Ra\x91\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x004\\\xbe\x01%H\x05e6o^Kg\xd3\x96L\x04\x9f~\xbf\xbe\x13[\x8aS\xbfO|&`}\xc6\xa5\xb1CJ\x93\x1d\x9a\x834R\xa7\xaa\xa1\x85F\xfae^\n\xcfM\\\nS\n\x89\x85%X+\xec\xac:\x89J\xe2W\xc0Ue\xeb\x8e\xa2r\xa4\xaa.Sk\x97\x19G8\xaf\x92\xb9\xca%i\xd4s\xc2\xc6]\x0e\x
*\x9a\xae\xa4\xc9(\x92\x06L\xbe\x89%i\xa6\xa1M\x91\xd4\xab\x1dR\x16\x89h+w\x9d%\x13\x0f\x029\xee\xdeP\x8b\xb1\x8ew\xab\x909b:x\r\xe7\xdc\x8fY\xa9\xb5\x9c\xce\xf2s\'\xc7r\xe2,\xd4\x99e:N:\xf7G\x99Z\x05&\xc1\x04b\x07"\x0e`\x83\xba4U5\xf3\xa6\x8a\xc6\xfe\xf7\xa2%bn\xdb\\B\x94Z(4\nzTkFM;\x9e\x06\xe1\xb8\xa5N\xd6B\xf6\x17C\x9aX\xe1-p \x83\xa1\x07P\xbc\xd7l\xb6k\xe8\x91V\x96#E\xc7\t\x072\xc2t\x93\xbc\x14Kr\xde\x9b\xa8\xfb%\xfc\x16\xdc\xa7%\xba\xd4;\xa5\x0e\xb8\x1f-\x08\xa5\x7fT\xa9\xa5\xe4z"\xed\xdbz\xfaWSv\xa1\x1d\xf9\xaf;\xbck\x9av\x92\xe1\xc7\xdc\x9d\xae\x8bp\xaa\xc0AM\xcd\x8e\x92\x92\x06\x12\xb6\xd1\xb4(\xdam-\xa4\xc7T~\x8d\x1egp\nT\xf3I;c{v\xaf\xec\x98{\x8c9\x9e.\xdf\xe4\x97\x8b\x1e\xb9Q\xd9%\xa5X&\xf1\xb6\xbe\xbdW=\xdb\xf4\x1c\x06\xe0\xa8#pR\x88\x1c\xd4@\xf3:\xafQ$\x95"\x17\xf2\xc9Sd\xe4\x13\x05\xcbp\xf6\ ...
# ****************************************************************************************************

# %%
from imapy.query_builder import Q

# %%
q = Q()
# Get all unseen emails in inbox
messages = mailbox.folder('INBOX').emails(
    q.unanswered().unseen()
)

# %%
show_messages(messages)
# Out:
# ----------------------------------------------------------------------------------------------------
# Subject:  Test
# From:  11510035@mail.sustc.edu.cn
# To:  pengym_111@163.com
# Date:  Tue, 12 Dec 2017 11:09:30 +0800
# ****************************************************************************************************
# Content:
# Hello world
#
# 树礼书院
# 彭一明
#
# Attachments:  []
# ****************************************************************************************************

# %% [markdown]
# ## 发送邮件

# %%
import smtplib
from email.mime.text import MIMEText
from email.header import Header
from email.mime.application import MIMEApplication
from email.mime.multipart import MIMEMultipart
from email.utils import COMMASPACE, formatdate
import os.path

# %%
def send_mail(conf, receivers, subject, content, attachments=None):
    account = conf['account']
    password = conf['password']
    
    message = MIMEMultipart()
    message['From'] = account
    message['To'] = ';'.join(receivers)
    message['Subject'] = subject
    message['Date'] = formatdate(localtime=True)
    message.attach(MIMEText(content))
    
    for f in attachments or []:
        with open(f, 'rb') as fil:
            part = MIMEApplication(
                fil.read(),
                Name = os.path.basename(f)
            )
        part['Content-Disposition'] = 'attachment; filename=%s' % os.path.basename(f)
        message.attach(part)
    
    try:
        smtpObj = smtplib.SMTP()
        smtpObj.connect(user_config['smtp_server'], user_config['smtp_port'])
        smtpObj.login(account, password)
        smtpObj.sendmail(account.format(account), receivers, message.as_string())
        smtpObj.close()
    except smtplib.SMTPException as e:
        print("Error: Unable to send email!")

# %%
send_mail(user_config, ['1048217874@qq.com'], '辣鸡，Project 做完了吗?', 'hhhhh', ['lenna.jpeg'])

# %% [markdown]
# ## UUID生成器

# %%
import uuid

# %%
code = uuid.uuid1()

# %%
print(code)
